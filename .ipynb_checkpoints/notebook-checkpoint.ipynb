# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np
import statsmodels.api as sm

data = pd.read_csv("soccer.csv") 
# Preview the first 5 lines of the loaded data

# %%
data
# Out:
#           Observation   Odds  Ranking  Ranking Difference  Home(1) / Away(0)  \
# 0             Caen 20   3.60       16                 -14                  1
# 1            Lille 20   2.20        2                  14                  0
# 2            Paris 20   1.20        1                  16                  0
# 3      Montpellier 20   2.20        5                  13                  0
# 4             Lyon 20   1.45        3                   8                  1
# 5        Marseille 20   1.75        6                  13                  1
# 6    Saint-Etienne 20   2.75        4                  16                  0
# 7             Nice 20   2.60        7                   5                  1
# 8            Nimes 20   2.20       10                   5                  1
# 9       Strasbourg 20   3.50        8                   6                  0
# 10        Bordeaux 20   2.90       12                  -5                  0
# 11           Reims 20   6.50       11                  -8                  0
# 12          Nantes 20   2.70       13                  -4                  1
# 13          Rennes 20   2.70        9                   4                  0
# 14          Angers 20   3.50       15                  -5                  0
# 15        Toulouse 20   2.15       14                  -6                  1
# 16           Dijon 20   3.25       18                 -13                  1
# 17          Monaco 20   3.90       19                 -13                  0
# 18          Amiens 20  13.00       17                 -16                  1
# 19        Guingamp 20   2.70       20                 -16                  1
# 20           Paris 21   1.05        1                  19                  1
# 21           Lille 21   1.60        2                  15                  1
# 22   Saint-Etienne 21   3.40        3                   1                  1
# 23            Lyon 21   2.05        4                  -1                  0
# 24     Montpellier 21   3.90        5                   4                  0
# 25       Marseille 21   1.75        6                  10                  0
# 26            Nice 21   3.70        7                   4                  0
# 27      Strasbourg 21   4.25        8                  11                  0
# 28          Rennes 21   2.00        9                  -4                  1
# 29           Nimes 21   1.95       10                   4                  1
# ..                ...    ...      ...                 ...                ...
# 110          Nimes 25   1.95       11                   6                  1
# 111         Angers 25   2.00       12                  -5                  1
# 112       Bordeaux 25   2.05       13                   2                  1
# 113         Nantes 25   4.75       14                   4                  0
# 114       Toulouse 25   4.00       15                  -2                  0
# 115         Amiens 25   9.00       16                 -10                  0
# 116          Dijon 25   3.80       17                  -6                  0
# 117         Monaco 25   1.75       18                  -4                  1
# 118           Caen 25   3.20       19                 -10                  1
# 119       Guingamp 25  13.00       20                 -17                  0
# 120          Paris 26   1.20        1                   9                  1
# 121          Lille 26   2.60        2                   7                  0
# 122           Lyon 26   2.37        3                  13                  0
# 123      Marseille 26   2.60        4                   7                  0
# 124  Saint-Etienne 26   2.25        5                  13                  0
# 125    Montpellier 26   2.05        6                   1                  1
# 126          Reims 26   4.20        7                  -1                  0
# 127           Nice 26   3.00        8                   9                  0
# 128     Strasbourg 26   2.90        9                  -7                  1
# 129          Nimes 26  13.00       10                  -9                  0
# 130         Rennes 26   2.80       11                  -7                  1
# 131         Angers 26   3.00       12                   8                  0
# 132       Bordeaux 26   3.75       13                   1                  0
# 133         Nantes 26   2.10       14                  -1                  1
# 134       Toulouse 26   1.72       15                   4                  1
# 28                                                   0
# 29                                                   1
# ..                                                 ...
# 110                                                  0
# 111                                                  0
# 112                                                  1
# 113                                                  1
# 114                                                  0
# 115                                                  1
# 116                                                  1
# 117                                                  0
# 118                                                  0
# 119                                                  1
# 120                                                  0
# 121                                                  0
# 122                                                  0
# 123                                                  0
# 124                                                  0
# 125                                                  0
# 126                                                  1
# 127                                                  0
# 128                                                  0
# 129                                                  1
# 130                                                  0
# 131                                                  1
# 132                                                  0
# 133                                                  1
# 134                                                  1
# 135                                                  1
# 136                                                  1
# 137                                                  1
# 138                                                  0
# 139                                                  0
#
# [140 rows x 8 columns]

# %% [markdown]
# # Multivariate Regression

# %%
y = data['Odds']
X = data[['Ranking', 'Ranking Difference','Home(1) / Away(0)','Points earned on last five games','Win the last confrontation (Win=1, Not a win=0)','Loss in the last confrontation (Loss =1, Not a loss = 0)']]
regr = linear_model.LinearRegression()
regr.fit(X, y)
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  3.2970389131898417
# Coefficients:
#  [ 0.00701977 -0.24782619 -2.32996161  0.13665583  1.09667846  0.11861465]

# %% [markdown]
# # Odds vs Ranking

# %%
real_data=data[['Odds','Ranking', 'Ranking Difference','Home(1) / Away(0)','Points earned on last five games','Win the last confrontation (Win=1, Not a win=0)','Loss in the last confrontation (Loss =1, Not a loss = 0)']]
x1 = X[['Ranking']]
regr1 = sm.OLS(y,sm.add_constant(x1)).fit()
line_x = np.arange(0,25)
line_y = regr1.params[1] * line_x + regr1.params[0]
fig1 = plt.figure(figsize=(15,15))
plt.scatter(x1,y)
plt.plot(line_x,line_y,'r')
plt.xlabel('Rankings', fontsize=18)
plt.ylabel('Odds', fontsize=18)
plt.title('Odds vs Rankings', fontsize=18)
# Out:
# Text(0.5,1,'Odds vs Rankings')

# %%
regr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Odds   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     12.39
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):           0.000586
# Time:                        21:37:59   Log-Likelihood:                -373.27
# No. Observations:                 140   AIC:                             750.5
# Df Residuals:                     138   BIC:                             756.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.6853      0.616      2.738      0.007       0.468       2.902
# Ranking        0.1809      0.051      3.520      0.001       0.079       0.282
# ==============================================================================
# Omnibus:                      206.558   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14246.667
# Skew:                           5.974   Prob(JB):                         0.00
# Kurtosis:                      50.954   Cond. No.                         25.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Odds vs Ranking Difference

# %%
x2 = X[['Ranking Difference']]
regr2 = sm.OLS(y,sm.add_constant(x2)).fit()
line_x = np.arange(-20,20)
line_y = regr2.params[1] * line_x + regr2.params[0]
fig1 = plt.figure(figsize=(15,15))
plt.scatter(x2,y)
plt.plot(line_x,line_y,'r')
plt.xlabel('Ranking Difference', fontsize=18)
plt.ylabel('Odds', fontsize=18)
plt.title('Odds vs Ranking Difference', fontsize=18)
# Out:
# Text(0.5,1,'Odds vs Ranking Difference')

# %%
regr2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Odds   R-squared:                       0.203
# Model:                            OLS   Adj. R-squared:                  0.197
# Method:                 Least Squares   F-statistic:                     35.14
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):           2.34e-08
# Time:                        21:42:01   Log-Likelihood:                -363.41
# No. Observations:                 140   AIC:                             730.8
# Df Residuals:                     138   BIC:                             736.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  3.5829      0.276     12.974      0.000       3.037       4.129
# Ranking Difference    -0.1925      0.032     -5.928      0.000      -0.257      -0.128
# ==============================================================================
# Omnibus:                      204.205   Durbin-Watson:                   2.266
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14669.738
# Skew:                           5.818   Prob(JB):                         0.00
# Kurtosis:                      51.779   Cond. No.                         8.51
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Odd vs Home(1) / Away(0)

# %%
x3 = X[['Home(1) / Away(0)']]
regr3 = sm.OLS(y,sm.add_constant(x3)).fit()
line_x = np.arange(0,2)
line_y = regr3.params[1] * line_x + regr3.params[0]
fig1 = plt.figure(figsize=(15,15))
plt.scatter(x3,y)
plt.plot(line_x,line_y,'r')
plt.xlabel('Home(1) / Away(0)', fontsize=18)
plt.ylabel('Odds', fontsize=18)
plt.title('Odds vs Home(1) / Away(0)', fontsize=18)
# Out:
# Text(0.5,1,'Odds vs Home(1) / Away(0)')

# %%
regr3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Odds   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     10.15
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):            0.00178
# Time:                        21:42:07   Log-Likelihood:                -374.32
# No. Observations:                 140   AIC:                             752.6
# Df Residuals:                     138   BIC:                             758.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.5354      0.422     10.742      0.000       3.701       5.370
# Home(1) / Away(0)    -1.9023      0.597     -3.186      0.002      -3.083      -0.722
# ==============================================================================
# Omnibus:                      212.442   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16183.049
# Skew:                           6.243   Prob(JB):                         0.00
# Kurtosis:                      54.170   Cond. No.                         2.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Odds vs Points earned on last five games

# %%
x4 = X[['Points earned on last five games']]
regr4 = sm.OLS(y,sm.add_constant(x4)).fit()
line_x = np.arange(0,17)
line_y = regr4.params[1] * line_x + regr4.params[0]
fig1 = plt.figure(figsize=(15,15))
plt.scatter(x4,y)
plt.plot(line_x,line_y,'r')
plt.xlabel('Points earned on last five games', fontsize=18)
plt.ylabel('Odds', fontsize=18)
plt.title('Odds vs Points earned on last five games', fontsize=18)
# Out:
# Text(0.5,1,'Odds vs Points earned on last five games')

# %%
regr4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Odds   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.436
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):              0.233
# Time:                        21:45:37   Log-Likelihood:                -378.56
# No. Observations:                 140   AIC:                             761.1
# Df Residuals:                     138   BIC:                             767.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                4.3936      0.742      5.920      0.000       2.926       5.861
# Points earned on last five games    -0.1195      0.100     -1.198      0.233      -0.317       0.078
# ==============================================================================
# Omnibus:                      212.236   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15777.830
# Skew:                           6.247   Prob(JB):                         0.00
# Kurtosis:                      53.485   Cond. No.                         18.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Odds vs Win the last confrontation (Win=1, Not a win=0)

# %%
x5 = X[['Win the last confrontation (Win=1, Not a win=0)']]
regr5 = sm.OLS(y,sm.add_constant(x5)).fit()
line_x = np.arange(0,2)
line_y = regr5.params[1] * line_x + regr5.params[0]
fig1 = plt.figure(figsize=(15,15))
plt.scatter(x5,y)
plt.plot(line_x,line_y,'r')
plt.xlabel('Win the last confrontation (Win=1, Not a win=0)', fontsize=18)
plt.ylabel('Odds', fontsize=18)
plt.title('Odds vs Win the last confrontation (Win=1, Not a win=0)', fontsize=18)
# Out:
# Text(0.5,1,'Odds vs Win the last confrontation (Win=1, Not a win=0)')

# %%
regr5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Odds   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.2646
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):              0.608
# Time:                        21:45:42   Log-Likelihood:                -379.15
# No. Observations:                 140   AIC:                             762.3
# Df Residuals:                     138   BIC:                             768.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                               3.7065      0.390      9.509      0.000       2.936       4.477
# Win the last confrontation (Win=1, Not a win=0)    -0.3290      0.640     -0.514      0.608      -1.594       0.936
# ==============================================================================
# Omnibus:                      213.057   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16249.725
# Skew:                           6.277   Prob(JB):                         0.00
# Kurtosis:                      54.265   Cond. No.                         2.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Odds vs Loss in the last confrontation (Loss =1, Not a loss = 0)

# %%
x6 = X[['Loss in the last confrontation (Loss =1, Not a loss = 0)']]
regr6 = sm.OLS(y,sm.add_constant(x6)).fit()
line_x = np.arange(0,2)
line_y = regr6.params[1] * line_x + regr6.params[0]
fig1 = plt.figure(figsize=(15,15))
plt.scatter(x6,y)
plt.plot(line_x,line_y,'r')
plt.xlabel('Loss in the last confrontation (Loss =1, Not a loss = 0)', fontsize=18)
plt.ylabel('Odds', fontsize=18)
plt.title('Odds vs Loss in the last confrontation (Loss =1, Not a loss = 0)', fontsize=18)
# Out:
# Text(0.5,1,'Odds vs Loss in the last confrontation (Loss =1, Not a loss = 0)')

# %%
regr5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Odds   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.2646
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):              0.608
# Time:                        21:47:19   Log-Likelihood:                -379.15
# No. Observations:                 140   AIC:                             762.3
# Df Residuals:                     138   BIC:                             768.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                               3.7065      0.390      9.509      0.000       2.936       4.477
# Win the last confrontation (Win=1, Not a win=0)    -0.3290      0.640     -0.514      0.608      -1.594       0.936
# ==============================================================================
# Omnibus:                      213.057   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16249.725
# Skew:                           6.277   Prob(JB):                         0.00
# Kurtosis:                      54.265   Cond. No.                         2.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Correlation Check

# %%
corr = real_data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(real_data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(real_data.columns)
ax.set_yticklabels(real_data.columns)
plt.show()

# %% [markdown]
# As shown in the correlation figure, the "Ranking Difference" variable has least correlation with Odds.

# %% [markdown]
# So, without "Ranking Difference" variable, the multivariate regression is:
